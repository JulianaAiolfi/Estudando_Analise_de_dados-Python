# %% [markdown]
# <a href="https://colab.research.google.com/github/JulianaAiolfi/Estudando_Analise_de_dados-Python/blob/main/Notebook_Aulas/Aula04_24_03_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("world_happiness_report_2015.csv")
df_bank = pd.read_excel("bank-full.xlsx", sheet_name="Sheet 1 - bank-full")

# %%
#df.head()
df_bank.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome  \
# 0  unknown    5   may       261         1     -1         0  unknown
# 1  unknown    5   may       151         1     -1         0  unknown
# 2  unknown    5   may        76         1     -1         0  unknown
# 3  unknown    5   may        92         1     -1         0  unknown
# 4  unknown    5   may       198         1     -1         0  unknown
#
#   Unnamed: 16
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
df_bank.education.value_counts()
# Out:
# secondary    23202
# tertiary     13301
# primary       6851
# unknown       1857
# Name: education, dtype: int64

# %%
df_bank.marital.value_counts()
# Out:
# married     27214
# single      12790
# divorced     5207
# Name: marital, dtype: int64

# %%
df_bank.month.value_counts()
# Out:
# may    13766
# jul     6895
# aug     6247
# jun     5341
# nov     3970
# apr     2932
# feb     2649
# jan     1403
# oct      738
# sep      579
# mar      477
# dec      214
# Name: month, dtype: int64

# %%
df_bank.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
df_bank.balance.mean()
# Out:
# 1362.2720576850766

# %%
if( df_bank.balance.mean() > 2000 ):
  print("média boa")
else:
  print("média ruim")
# Out:
# média ruim

# %%
df_bank[['balance','duration']].mean()
# Out:
# balance     1362.272058
# duration     258.163080
# dtype: float64

# %%
df_bank.balance.sum()
# Out:
# 61589682

# %%
df_bank[['balance','duration']].sum()
# Out:
# balance     61589682
# duration    11671811
# dtype: int64

# %%
#
df_bank.balance.max()
# Out:
# 102127

# %%
df_bank.balance.median()
# Out:
# 448.0

# %%
df_bank.balance.min()
# Out:
# -8019

# %%
df_bank.balance.std()
# Out:
# 3044.7658291686002

# %%
df_bank.balance.count()
# Out:
# 45211

# %%
#mostra os valores unicos da tabela
print(df_bank.job.unique())
# Out:
# ['management' 'technician' 'entrepreneur' 'blue-collar' 'unknown'
#  'retired' 'admin.' 'services' 'self-employed' 'unemployed' 'housemaid'
#  'student']

# %%
#quandidade de profissões preenchidas
df_bank.job.nunique()
# Out:
# 12

# %%
df_bank.job.value_counts()
# Out:
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# unknown           288
# Name: job, dtype: int64

# %%
#
df_bank.loc[:,["job","marital","education","balance","month"]].duplicated().sum()
# Out:
# 6586

# %%
df_bank.duplicated().sum()
# Out:
# 0

# %%
df_bank.drop_duplicates()
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
#mostra os valores duplicados
df_bank.loc[df_bank.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, default, balance, housing, loan, contact, day, month, duration, campaign, pdays, previous, poutcome, Unnamed: 16]
# Index: []

# %%
#df_bank.isna().sum() 
df_bank.isnull().sum()
# Out:
# age                0
# job                0
# marital            0
# education          0
# default            0
# balance            0
# housing            0
# loan               0
# contact            0
# day                0
# month              0
# duration           0
# campaign           0
# pdays              0
# previous           0
# poutcome           0
# Unnamed: 16    45208
# dtype: int64

# %%
#delete todas as linhas que tem pelo menos 1 coluna em branco
df_bank.dropna()
# Out:
#        age           job  marital  education default  balance housing loan  \
# 45208   72       retired  married  secondary      no     5715      no   no
# 45209   57   blue-collar  married  secondary      no      668      no   no
# 45210   37  entrepreneur  married  secondary      no     2971      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome  \
# 45208   cellular   17   nov      1127         5    184         3  success
# 45209  telephone   17   nov       508         4     -1         0  unknown
# 45210   cellular   17   nov       361         2    188        11    other
#
#       Unnamed: 16
# 45208       False
# 45209       False
# 45210       False

# %%
df_bank2 = df_bank.score_felicidade.fillna(99999)
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
df = pd.read_csv("world_happiness_report_2015.csv")
df.rename(columns = {"happiness rank": "score_felicidade","happiness score": "score_felicidade", "standard error": "stand_error", "economy (GDP per Capita)": "PIB", "health (Life Expectancy)": "expect_vida", "trust (Government Corruption)": "corrupcao" }, inplace = True)

# %%
df.columns
# Out:
# Index(['country', 'region', 'rank_felicidade', 'score_felicidade',
#        'stand_error', 'PIB', 'family', 'expect_vida', 'freedom', 'corrupcao',
#        'generosity', 'dystopia residual'],
#       dtype='object')

# %%
df.score_felicidade.mean()
# Out:
# 5.424487179487181

# %%
df.PIB.sum()
# Out:
# 141.37172

# %%
df.loc[:,['freedom','corrupcao']].sum()
df[['freedom','corrupcao']].sum()
# Out:
# freedom      71.33320
# corrupcao    24.59645
# dtype: float64

# %%
df.freedom.sum(),df.corrupcao.sum()
# Out:
# (71.3332, 24.596449999999997)

# %%
df.duplicated().sum()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 159    False
# 160    False
# 161    False
# 162    False
# 163    False
# Length: 164, dtype: bool

# %%
df.loc[df.duplicated() == True]
# Out:
#         country                           region  rank_felicidade  \
# 11       Canada                    North America                5
# 12      Finland                   Western Europe                6
# 13  Netherlands                   Western Europe                7
# 14       Sweden                   Western Europe                8
# 34         Oman  Middle East and Northern Africa               22
# 35    Venezuela      Latin America and Caribbean               23
#
#     score_felicidade  stand_error      PIB   family  expect_vida  freedom  \
# 11             7.427      0.03553  1.32629  1.32261      0.90563  0.63297
# 12             7.406      0.03140  1.29025  1.31826      0.88911  0.64169
# 13             7.378      0.02799  1.32944  1.28017      0.89284  0.61576
# 14             7.364      0.03157  1.33171  1.28907      0.91087  0.65980
# 34             6.853      0.05335  1.36011  1.08182      0.76276  0.63274
# ...

# %%
df.isna().sum()
#df.isnull().sum()
# Out:
# country               0
# region                0
# rank_felicidade       0
# score_felicidade      8
# stand_error           1
# PIB                   0
# family                0
# expect_vida           0
# freedom               0
# corrupcao             0
# generosity            0
# dystopia residual    14
# dtype: int64

# %%
df2 = df.score_felicidade.fillna(-99999)

# %%
df2
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 159    3.465
# 160    3.340
# 161    3.006
# 162    2.905
# 163    2.839
# Name: score_felicidade, Length: 164, dtype: float64

# %%
df.region.unique()
# Out:
# array(['Western Europe', 'North America', 'Australia and New Zealand',
#        'Middle East and Northern Africa', 'Latin America and Caribbean',
#        'Southeastern Asia', 'Central and Eastern Europe', 'Eastern Asia',
#        'Sub-Saharan Africa', 'Southern Asia'], dtype=object)

# %%
df.region.value_counts()
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Western Europe                     24
# Latin America and Caribbean        23
# Middle East and Northern Africa    21
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       3
# Australia and New Zealand           2
# Name: region, dtype: int64

# %%
df.region.min()
# Out:
# 'Australia and New Zealand'

# %%
df.region.max()
# Out:
# 'Western Europe'

# %%
df.describe(include='O').T
# Out:
#         count unique                 top freq
# country   164    158           Venezuela    2
# region    164     10  Sub-Saharan Africa   40

# %%
dados1 = {
          'ID': [1,2,3,4,5],
          'nome': ['Paula', 'Claudia','João','Carlos','Ana'],
          'sobrenome': ['Pereira', 'Silvia','Silveira','Bezerra','Souza']}
df1 = pd.DataFrame( data = dados1)
df1.head()

# %%
dados2 = {
          'ID': [6,7,8,9,10],
          'nome': ["Eder", "Joana",'Paulo',"Pedro",'Bete'],
          'sobrenome': ['Pereira', 'Silvia','Silveira','Bezerra','Souza']}
df2 = pd.DataFrame( data = dados2)
df2.head()
# Out:
#    ID   nome sobrenome
# 0   6   Eder   Pereira
# 1   7  Joana    Silvia
# 2   8  Paulo  Silveira
# 3   9  Pedro   Bezerra
# 4  10   Bete     Souza

# %%
notas = { "ID": [1,2,3,4,5,6,7,8,9,50],
          "notas": [10,22,33,44,25,26,47,38,19,50] }
df3 = pd.DataFrame( data = notas)
df3.head()
# Out:
#    ID  notas
# 0   1     10
# 1   2     22
# 2   3     33
# 3   4     44
# 4   5     25

# %%
#junta 
df_new = pd.concat([df1,df2,df_new])
df_new
# Out:
#    ID     nome sobrenome
# 0   1    Paula   Pereira
# 1   2  Claudia    Silvia
# 2   3     João  Silveira
# 3   4   Carlos   Bezerra
# 4   5      Ana     Souza
# 0   6     Eder   Pereira
# 1   7    Joana    Silvia
# 2   8    Paulo  Silveira
# 3   9    Pedro   Bezerra
# 4  10     Bete     Souza
# 0   1    Paula   Pereira
# 1   2  Claudia    Silvia
# 2   3     João  Silveira
# 3   4   Carlos   Bezerra
# 4   5      Ana     Souza
# 0   6     Eder   Pereira
# 1   7    Joana    Silvia
# 2   8    Paulo  Silveira
# 3   9    Pedro   Bezerra
# 4  10     Bete     Souza

# %%
df_notas = pd.merge(df_new, df3, on = 'ID')
df_notas
# Out:
#    ID     nome sobrenome  notas
# 0   1    Paula   Pereira     10
# 1   2  Claudia    Silvia     22
# 2   3     João  Silveira     33
# 3   4   Carlos   Bezerra     44
# 4   5      Ana     Souza     25
# 5   6     Eder   Pereira     26
# 6   7    Joana    Silvia     47
# 7   8    Paulo  Silveira     38
# 8   9    Pedro   Bezerra     19
# 9  10     Bete     Souza     30

# %%
#df_notas = pd.merge(df_new, df3, on = 'ID', how= 'inner')
#df_notas = pd.merge(df_new, df3, on = 'ID', how= 'left')
#df_notas = pd.merge(df_new, df3, on = 'ID', how= 'right')
df_notas = pd.merge(df_new, df3, on = 'ID')

df_notas
# Out:
#    ID     nome sobrenome  notas
# 0   1    Paula   Pereira     10
# 1   2  Claudia    Silvia     22
# 2   3     João  Silveira     33
# 3   4   Carlos   Bezerra     44
# 4   5      Ana     Souza     25
# 5   6     Eder   Pereira     26
# 6   7    Joana    Silvia     47
# 7   8    Paulo  Silveira     38
# 8   9    Pedro   Bezerra     19

# %%
df_bank
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
df_bank.groupby(['job','marital']).count()
# Out:
#                          age  education  default  balance  housing  loan  \
# job           marital
# admin.        divorced   750        750      750      750      750   750
#               married   2693       2693     2693     2693     2693  2693
#               single    1728       1728     1728     1728     1728  1728
# blue-collar   divorced   750        750      750      750      750   750
#               married   6968       6968     6968     6968     6968  6968
#               single    2014       2014     2014     2014     2014  2014
# entrepreneur  divorced   179        179      179      179      179   179
#               married   1070       1070     1070     1070     1070  1070
#               single     238        238      238      238      238   238
# housemaid     divorced   184        184      184      184      184   184
#               married    912        912      912      912      912   912
# ...

# %%
df_bank.groupby(['job','marital']).median()
# Out:
#                          age  balance   day  duration  campaign  pdays  \
# job           marital
# admin.        divorced  42.0    337.5  15.0     181.5       2.0   -1.0
#               married   40.0    423.0  16.0     169.0       2.0   -1.0
#               single    32.0    391.0  15.0     178.5       2.0   -1.0
# blue-collar   divorced  43.0    220.5  15.0     186.5       2.0   -1.0
#               married   41.0    420.0  15.0     182.0       2.0   -1.0
#               single    32.0    341.0  15.0     198.0       2.0   -1.0
# entrepreneur  divorced  46.0    299.0  16.0     177.0       2.0   -1.0
#               married   42.0    391.0  17.0     175.0       2.0   -1.0
#               single    34.0    318.0  17.0     197.0       2.0   -1.0
# housemaid     divorced  51.0    452.5  17.0     159.0       2.0   -1.0
#               married   47.0    379.0  16.0     162.5       2.0   -1.0
#               single    37.0    650.0  15.5     175.0       2.0   -1.0
# ...

# %%
df_bank.groupby(['job','marital']).std()
# Out:
#                               age      balance       day    duration  \
# job           marital
# admin.        divorced   8.451030  1736.604668  8.430294  242.994258
#               married    9.261378  2931.495552  8.374254  240.999343
#               single     7.622093  2473.221599  8.613919  236.389945
# blue-collar   divorced   8.392529  1661.435574  7.628153  286.496898
#               married    8.697463  2311.386022  7.900267  250.177894
#               single     7.164189  2172.530935  7.932571  284.353269
# entrepreneur  divorced   8.033614  2993.955852  7.991019  233.428198
#               married    8.872609  4254.939605  7.694763  245.937849
#               single     7.578248  4419.106882  8.638283  265.264584
# housemaid     divorced  10.250844  3846.967439  7.812818  270.893137
#               married   10.086162  2380.285525  8.072524  245.462878
#               single     9.752732  4637.718915  8.564396  321.192540
# ...

# %%
df_bank.groupby(['job','marital']).sum()
# Out:
#                            age  balance     day  duration  campaign   pdays  \
# job           marital
# admin.        divorced   32308   658750   11569    194959      1795   41624
#               married   111766  3450836   42476    653852      7260  112605
#               single     59094  1763837   26438    427892      4262   93250
# blue-collar   divorced   32620   615605   11228    205090      1931   35406
#               married   289519  7756540  108033   1781209     20194  296878
#               single     67570  2126996   31026    572259      5290   96250
# entrepreneur  divorced    8196   206921    2767     45895       489    5168
#               married    46118  1758425   16860    268601      3107   34909
#               single      8424   297080    3722     66636       567    8230
# housemaid     divorced    9225   289473    2955     47457       469    3822
#               married    42706  1138334   14688    216639      2674   17531
# ...

# %%
#       as colunas da grupo            as metricas de calculo    as colunas que estão calculadas
df_bank.groupby(['gender','Favorite Color']).count()[['balance','duration']]
# Out:
#                             balance             duration
#                                mean      sum        mean      sum
# job           marital
# admin.        divorced   878.333333   658750  259.945333   194959
#               married   1281.409580  3450836  242.796881   653852
#               single    1020.739005  1763837  247.622685   427892
# blue-collar   divorced   820.806667   615605  273.453333   205090
#               married   1113.165901  7756540  255.627009  1781209
#               single    1056.105263  2126996  284.140516   572259
# entrepreneur  divorced  1155.983240   206921  256.396648    45895
#               married   1643.387850  1758425  251.028972   268601
#               single    1248.235294   297080  279.983193    66636
# housemaid     divorced  1573.222826   289473  257.918478    47457
#               married   1248.173246  1138334  237.542763   216639
#               single    2074.743056   298763  282.826389    40727
# ...

# %%
df_bank.groupby(['month','day']).agg(['sum'])['balance']
# Out:
#               sum
# month day
# apr   1    176755
#       2     59687
#       3     83177
#       5     52084
#       6    154882
# ...           ...
# sep   26      670
#       27    12134
#       28    20116
#       29     9669
#       30    15779
#
# [318 rows x 1 columns]
